# %% [markdown]
# # Usecase
# ## Aim
# With the simulated dataset from the aircraft Turbofan engines' simulation in NASA Ames Prognostics Data Repository, we will build Machine Learning models to predict the Remaining Useful Life (RUL) of aircraft engine.
#
# ## Objectives
# To keep the problem simple, we model it to predict the time period where the engine will fail with the thresholds of 20 and 50 engine cycles (flights).
#
# + First we will explore the dataset
# + Clease and transform into the suitable format for the model input
# + Build several models to compared among them in model performance assessment.

# %%
w0 = 20
w1 = 50

# %% [markdown]
# # Introduction
#
# ## Experimental Scenario
#
#
# The engine is operating normally at the start of each time series, and develops a fault at some point during the operations.
#
# In the training set, the fault grows in magnitude until system failure. In the test set, the time series ends some time prior to system failure.
#
# The objective of the task is to predict the number of remaining operational cycles before failure in the test set, i.e., the number of operational cycles after the last cycle that the engine will continue to operate. Also provided a vector of true Remaining Useful Life (RUL) values for the test data.
#
#
# ## Datasets
#
#
# The dataset consists of three multivariate time series files. It is divided into training and test subset. There is also a truth label dataset, where it shows the outcome of previous test cases.
#
# Each time series is from a different engine  i.e., the data can be considered to be from a fleet of engines of the same type. Each engine starts with different degrees of initial wear and manufacturing variation which is unknown to the user. This wear and variation is considered normal, i.e., it is not considered a fault condition.
#
# There are three operational settings that have a substantial effect on engine performance. These settings are also included in the data. The data is contaminated with sensor noise.
#
# The data are provided as a zip-compressed text file with 26 columns of numbers, separated by spaces. Each row is a snapshot of data taken during a single operational cycle, each column is a different variable. The columns correspond to:
#
# + unit number
# + time, in cycles
# + operational setting 1
# + operational setting 2
# + operational setting 3
#
# + And the 21 other sensors
#
# | Symbol | Description | Units |
# | --- | --- | --- |
# | T2 | Total temperature at fan inlet   | °R  |
# | T24 | Total temperature at LPC outlet  | °R  |
# | T30 | Total temperature at HPC outlet  | °R  |
# | T50 | Total temperature at LPT outlet  | °R  |
# | P2 | Pressure at fan inlet  | psia |
# | P15 | Total pressure in bypass-duct  |  psia |
# | P30 | Total pressure at HPC outlet  |  psia |
# | Nf | Physical fan speed  | r/min |
# | Nc | Physical core speed  | r/min |
# | epr | Engine pressure ratio (P50/P2)  | –  |
# | Ps30 | Static pressure at HPC outlet  | psia | |
# | phi | Ratio of fuel flow to Ps30  | pps/psi |
# | NRf | Corrected fan speed  | r/min | |
# | NRc | Corrected core speed  | r/min |
# | BPR | Bypass Ratio  | – |
# | farB | Burner fuel-air ratio  | – |
# | htBleed | Bleed Enthalpy  | – |
# | Nf_dmd | Demanded fan speed  |  r/min |
# | PCNfR_dmd | Demanded corrected fan speed  |  r/min |
# | W31 | HPT coolant bleed  | lbm/s |
# | W32  | LPT coolant bleed   | lbm/s |
#
# These are the parameters for monitoring Aircraft Engine.

# %%
print('Data files: ')
# !ls ../data
# Out:
# Data files:
# PM_test.txt  PM_train.txt  PM_truth.txt  readme.txt

# %% [markdown]
# # Data Exploration

# %%
# import packages
import pandas as pd
import numpy as np
import itertools
import matplotlib
import sklearn
import seaborn as sns
sns.set(style="whitegrid")

from tensorflow import keras
import tensorflow as tf
from sklearn import preprocessing
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, roc_auc_score, classification_report, plot_confusion_matrix, accuracy_score
from sklearn.preprocessing import MinMaxScaler, StandardScaler

from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import ModelCheckpoint

import warnings
warnings.filterwarnings("ignore")

import io
import plotly.offline as py
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.tools as tls
import plotly.figure_factory as ff
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
print('tensorflow', tf.__version__,'sklearn', sklearn.__version__,'matplotlib', matplotlib.__version__, 'pandas', pd.__version__)
# Out:
# tensorflow 1.15.2 sklearn 0.22.1 matplotlib 3.0.2 pandas 0.25.3

# %% [markdown]
# ## Load train data

# %%
train_df = pd.read_csv('../data/PM_train.txt', sep=" ", header=None)
train_df.drop(train_df.columns[[26, 27]], axis=1, inplace=True)
train_df.columns = ['id', 'cycle','setting_1','setting_2','setting_3','T2','T24','T30','T50','P2','P15','P30','Nf',
                    'Nc','epr','Ps30','phi','NRf','NRc','BPR','farB','htBleed','Nf_dmd','PCNfR_dmd','W31','W32']
print('Number of engine #id:',len(train_df.id.unique()))
train_df = train_df.sort_values(['id','cycle'])
print('Number of engine cycles (rows) in the training data: ', train_df.shape[0])
train_df.head(3)
# Out:
# Number of engine #id: 100
# Number of engine cycles (rows) in the training data:  20631
#    id  cycle  setting_1  setting_2  setting_3      T2     T24      T30  \
# 0   1      1    -0.0007    -0.0004      100.0  518.67  641.82  1589.70
# 1   1      2     0.0019    -0.0003      100.0  518.67  642.15  1591.82
# 2   1      3    -0.0043     0.0003      100.0  518.67  642.35  1587.99
#
#        T50     P2  ...     phi      NRf      NRc     BPR  farB  htBleed  \
# 0  1400.60  14.62  ...  521.66  2388.02  8138.62  8.4195  0.03      392
# 1  1403.14  14.62  ...  522.28  2388.07  8131.49  8.4318  0.03      392
# 2  1404.20  14.62  ...  522.42  2388.03  8133.23  8.4178  0.03      390
#
#    Nf_dmd  PCNfR_dmd    W31      W32
# 0    2388      100.0  39.06  23.4190
# 1    2388      100.0  39.00  23.4236
# 2    2388      100.0  38.95  23.3442
#
# [3 rows x 26 columns]

# %% [markdown]
# **Remaining Useful Life** (number engine cycles before an event)

# %%
train_df['RUL']=train_df.groupby(['id'])['cycle'].transform(max)-train_df['cycle']
train_df.RUL[0:10]
# Out:
# 0    191
# 1    190
# 2    189
# 3    188
# 4    187
# 5    186
# 6    185
# 7    184
# 8    183
# 9    182
# Name: RUL, dtype: int64

# %% [markdown]
# ### Data Quality Assestment - Check missing values
# Why have I chosen a specific method for data quality assessment?
#
# Since we use the cleaned simulated data, there is no missing values, however, there are several redundant columns which  have the same constant values for all engine cycles.

# %%
train_df.isnull().sum().sum()
# Out:
# 0

# %%
### SCALE TRAIN DATA ###

def scale(df):
    return (df - df.min())/(df.max()-df.min())

for col in train_df.columns[2:-1]:
    train_df[col] = scale(train_df[col])
        
# Drop several redundant columns
train_df = train_df.dropna(axis=1)

train_df.head()
# Out:
#    id  cycle  setting_1  setting_2       T24       T30       T50  P15  \
# 0   1      1   0.459770   0.166667  0.183735  0.406802  0.309757  1.0
# 1   1      2   0.609195   0.250000  0.283133  0.453019  0.352633  1.0
# 2   1      3   0.252874   0.750000  0.343373  0.369523  0.370527  1.0
# 3   1      4   0.540230   0.500000  0.343373  0.256159  0.331195  1.0
# 4   1      5   0.390805   0.333333  0.349398  0.257467  0.404625  1.0
#
#         P30        Nf        Nc      Ps30       phi       NRf       NRc  \
# 0  0.726248  0.242424  0.109755  0.369048  0.633262  0.205882  0.199608
# 1  0.628019  0.212121  0.100242  0.380952  0.765458  0.279412  0.162813
# 2  0.710145  0.272727  0.140043  0.250000  0.795309  0.220588  0.171793
# 3  0.740741  0.318182  0.124518  0.166667  0.889126  0.294118  0.174889
# 4  0.668277  0.242424  0.149960  0.255952  0.746269  0.235294  0.174734
#
#         BPR   htBleed       W31       W32  RUL
# 0  0.363986  0.333333  0.713178  0.724662  191
# 1  0.411312  0.333333  0.666667  0.731014  190
# 2  0.357445  0.166667  0.627907  0.621375  189
# 3  0.166603  0.333333  0.573643  0.662386  188
# 4  0.402078  0.416667  0.589147  0.704502  187

# %% [markdown]
# ### Data Visualisation with training set

# %%
### plotting sensor data for engine ID ###
engine_id = train_df[train_df['id'] == 1]
print('Time series visualisation w.r.t. cycle order of one sample aircraft engine')
ax = engine_id[train_df.columns[2:]].plot(subplots=True, sharex=True, figsize=(20,30))
# plt.xlabel('Engine Cycle Time')
#plt.ylabel('Values of Settings and sensors',)
# Out:
# Time series visualisation w.r.t. cycle order of one sample aircraft engine

# %%
### PLOT TRAIN FREQ ###
plt.figure(figsize=(8,20))
train_df.id.value_counts().plot.barh(color=list('rgbkymc'))
plt.title('Number of engine cycles for each engine from the start recording')
plt.ylabel('Engine ID')
plt.xlabel('cycles counts')

print("medium working time:", train_df.id.value_counts().mean())
print("max working time:", train_df.id.value_counts().max())
print("min working time:", train_df.id.value_counts().min())
# Out:
# medium working time: 206.31
# max working time: 362
# min working time: 128

# %%
#correlation
correlation = train_df.corr()
#tick labels
matrix_cols = correlation.columns.tolist()
#convert to array
corr_array  = np.array(correlation)

#Plotting
trace = go.Heatmap(z = corr_array,
                   x = matrix_cols,
                   y = matrix_cols,
                   colorscale = "Viridis",
                   colorbar   = dict(title = "Pearson Correlation coefficient",
                                     titleside = "right"
                                    ) ,
                  )

layout = go.Layout(dict(title = "Correlation Matrix for variables",
                        autosize = False,
                        height  = 720,
                        width   = 800,
                        margin  = dict(r = 0 ,l = 210,
                                       t = 25,b = 210,
                                      ),
                        yaxis   = dict(tickfont = dict(size = 9)),
                        xaxis   = dict(tickfont = dict(size = 9))
                       )
                  )

data = [trace]
fig = go.Figure(data=data,layout=layout)
py.iplot(fig)
# Out:
# <div>
#
#
#             <div id="aa99eae3-99b5-45fb-b2a0-0f2f1bc541d3" class="plotly-graph-div" style="height:720px; width:800px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("aa99eae3-99b5-45fb-b2a0-0f2f1bc541d3")) {
#                     Plotly.newPlot(
#                         'aa99eae3-99b5-45fb-b2a0-0f2f1bc541d3',
#                         [{"colorbar": {"title": {"side": "right", "text": "Pearson Correlation coefficient"}}, "colorscale": [[0.0, "#440154"], [0.1111111111111111, "#482878"], [0.2222222222222222, "#3e4989"], [0.3333333333333333, "#31688e"], [0.4444444444444444, "#26828e"], [0.5555555555555556, "#1f9e89"], [0.6666666666666666, "#35b779"], [0.7777777777777778, "#6ece58"], [0.8888888888888888, "#b5de2b"], [1.0, "#fde725"]], "type": "heatmap", "x": ["id", "cycle", "setting_1", "setting_2", "T24", "T30", "T50", "P15", "P30", "Nf", "Nc", "Ps30", "phi", "NRf", "NRc", "BPR", "htBleed", "W31", "W32", "RUL"], "y": ["id", "cycle", "setting_1", "setting_2", "T24", "T30", "T50", "P15", "P30", "Nf", "Nc", "Ps30", "phi", "NRf", "NRc", "BPR", "htBleed", "W31", "W32", "RUL"], "z": [[1.0, 0.07875253246984423, -0.017895087861725438, -0.006196537392321129, 0.014132767308928722, 0.01262126688653307, 0.02611584850621645, 0.026431499164544913, -0.03207257290366156, 0.039929449335583296, -0.052053280261627116, 0.024707135604637335, -0.03188234343322268, 0.044229819793782536, -0.0594734108746339, 0.022486320852605424, 0.013513343107886471, -0.020588576690197445, -0.016465128133848865, 0.07875253246984422], [0.07875253246984423, 1.0, -0.004526812733496799, 0.016132042942546124, 0.5498980406467414, 0.5439469967381734, 0.6245771663318059, 0.10597998498962072, -0.5959135558088287, 0.4759773188586818, 0.443999347239284, 0.6343845048360597, -0.6113536330275922, 0.47752296349693196, 0.37032363419775727, 0.5886757839101249, 0.5669949114523577, -0.583596891905946, -0.5859233821213246, -0.736240599307095], [-0.017895087861725438, -0.004526812733496799, 1.0, 0.011660441595287698, 0.009029868145910114, -0.0056511005036729125, 0.009543964889850641, -0.0013404100034679998, -0.00943732828162723, -0.000426686825712572, -0.004278809097775643, 0.0116578415332404, -0.0014907949465539938, 0.002317786694032219, -0.004469387706821822, 0.007651994563056479, 0.0025991979886578623, -0.0057126254664262004, -0.014558624214590183, -0.0031984575547410036], [-0.006196537392321129, 0.016132042942546124, 0.011660441595287698, 1.0, 0.007266241872177873, 0.00906783347813272, 0.014672839526541439, 0.014354580308528927, -0.01667789618949359, 0.01328472976726634, -0.0054249662386118115, 0.011690379032144578, -0.010922543944384312, 0.018156351080626458, -0.006310324293058934, 0.014156031526548221, 0.012279786815801568, -0.010554032598892451, -0.007845559001346446, -0.0019476283515006568], [0.014132767308928722, 0.5498980406467414, 0.009029868145910114, 0.007266241872177873, 1.0, 0.6026096254120042, 0.7149492357345346, 0.13224249106235555, -0.702136451246407, 0.6623249714772231, 0.2737642497711543, 0.7400200250827786, -0.7245784731487428, 0.6617924441455688, 0.1797520089810947, 0.6759751834688571, 0.6298855524725123, -0.6618407016053532, -0.6680502336446353, -0.6064839743783423], [0.01262126688653307, 0.5439469967381734, -0.0056511005036729125, 0.00906783347813272, 0.6026096254120042, 1.0, 0.6784127230560599, 0.11603935842635808, -0.6645953071132757, 0.6024805063925829, 0.32296440124717785, 0.6959001518952567, -0.6803068131690403, 0.6009632389134594, 0.2371372570993398, 0.6399212019115291, 0.6000172066356665, -0.6259414240528011, -0.6339008220838387, -0.5845203909175867], [0.02611584850621645, 0.6245771663318059, 0.009543964889850641, 0.014672839526541439, 0.7149492357345346, 0.6784127230560599, 1.0, 0.1504801279077477, -0.79312956151037, 0.7468516378386204, 0.297428604864041, 0.8301356963159796, -0.8155905161052392, 0.7451584171065162, 0.1907476635905288, 0.7584588237333929, 0.7034991076071135, -0.7480671529345555, -0.7451931072313087, -0.6789482333860494], [0.026431499164544913, 0.10597998498962072, -0.0013404100034679998, 0.014354580308528927, 0.13224249106235555, 0.11603935842635808, 0.1504801279077477, 1.0, -0.15572021582676482, 0.152160639361993, 0.019347241297221564, 0.16001446079009107, -0.1558837465080096, 0.15827624033977838, -0.0021123292259955903, 0.14904195424412797, 0.13080 ...

# %% [markdown]
# ## Load test data
# ### Input test feature data

# %%
test_df = pd.read_csv('../data/PM_test.txt', sep=" ", header=None)
test_df.drop(test_df.columns[[26, 27]], axis=1, inplace=True)
test_df.columns = ['id', 'cycle','setting_1','setting_2','setting_3','T2','T24','T30','T50','P2','P15','P30','Nf',
           'Nc','epr','Ps30','phi','NRf','NRc','BPR','farB','htBleed','Nf_dmd','PCNfR_dmd','W31','W32']
print('Number of engine #id:',len(test_df.id.unique()))
print(test_df.shape)
test_df.head(3)
# Out:
# Number of engine #id: 100
# (13096, 26)
#    id  cycle  setting_1  setting_2  setting_3      T2     T24      T30  \
# 0   1      1     0.0023     0.0003      100.0  518.67  643.02  1585.29
# 1   1      2    -0.0027    -0.0003      100.0  518.67  641.71  1588.45
# 2   1      3     0.0003     0.0001      100.0  518.67  642.46  1586.94
#
#        T50     P2  ...     phi      NRf      NRc     BPR  farB  htBleed  \
# 0  1398.21  14.62  ...  521.72  2388.03  8125.55  8.4052  0.03      392
# 1  1395.42  14.62  ...  522.16  2388.06  8139.62  8.3803  0.03      393
# 2  1401.34  14.62  ...  521.97  2388.03  8130.10  8.4441  0.03      393
#
#    Nf_dmd  PCNfR_dmd    W31      W32
# 0    2388      100.0  38.86  23.3735
# 1    2388      100.0  39.02  23.3916
# 2    2388      100.0  39.08  23.4166
#
# [3 rows x 26 columns]

# %% [markdown]
# ### Input the ground truth of test data

# %%
# this shows the number of more engine cycle the aircraft can be utilised
truth_df = pd.read_csv('../data/PM_truth.txt', sep=" ", header=None)
truth_df.drop(truth_df.columns[[1]], axis=1, inplace=True)
truth_df.columns = ['more']
truth_df = truth_df.set_index(truth_df.index + 1)

print(truth_df.shape)
truth_df.head(5)
# Out:
# (100, 1)
#    more
# 1   112
# 2    98
# 3    69
# 4    82
# 5    91

# %% [markdown]
# In this dataset, the total number of engine cycles of an aircraft engine = the max number of engine cycle in the test data and the extra number of cycles it can fly.

# %%
### CALCULATE RUL TEST ###
truth_df['max'] = test_df.groupby('id')['cycle'].max() + truth_df['more']
test_df['RUL'] = [truth_df['max'][i] for i in test_df.id] - test_df['cycle']

# %%
### SCALE TEST DATA ###

for col in test_df.columns[2:-1]:
    test_df[col] = scale(test_df[col])
        
# Make sure we drop the same set of cols with the training data
test_df = test_df.dropna(axis=1)
print(test_df.columns)
test_df.head()
# Out:
# Index(['id', 'cycle', 'setting_1', 'setting_2', 'T24', 'T30', 'T50', 'P15',
#        'P30', 'Nf', 'Nc', 'Ps30', 'phi', 'NRf', 'NRc', 'BPR', 'htBleed', 'W31',
#        'W32', 'RUL'],
#       dtype='object')
#    id  cycle  setting_1  setting_2       T24       T30       T50  P15  \
# 0   1      1    0.65625   0.692308  0.596215  0.421968  0.282214  1.0
# 1   1      2    0.34375   0.230769  0.182965  0.504025  0.225240  1.0
# 2   1      3    0.53125   0.538462  0.419558  0.464814  0.346130  1.0
# 3   1      4    0.77500   0.461538  0.413249  0.391587  0.449867  1.0
# 4   1      5    0.60000   0.461538  0.435331  0.471306  0.357974  1.0
#
#         P30        Nf        Nc      Ps30       phi       NRf       NRc  \
# 0  0.608871  0.365854  0.196475  0.273973  0.534247  0.325581  0.152259
# 1  0.800403  0.292683  0.229042  0.479452  0.634703  0.395349  0.277907
# 2  0.651210  0.390244  0.248506  0.479452  0.591324  0.325581  0.192892
# 3  0.643145  0.341463  0.159080  0.328767  0.456621  0.372093  0.217896
# 4  0.661290  0.292683  0.153410  0.349315  0.632420  0.325581  0.187891
#
#         BPR  htBleed       W31       W32  RUL
# 0  0.347076    0.375  0.500000  0.620099  142
# 1  0.227709    0.500  0.645455  0.645718  141
# 2  0.533557    0.500  0.700000  0.681104  140
# 3  0.282359    0.250  0.627273  0.620382  139
# 4  0.337009    0.125  0.618182  0.676008  138

# %% [markdown]
# # Feature Engineering
# ### Add new train label as categorical variable
#
#
# Why have I chosen a specific method for feature engineering?
#
# We will use label2 as the main target y and transform the continuous variable to the categorical format, where
#
# + label2=0 if RUL<=20,
# + label2=1 if 20<RUL<=50, and
# + label2=2 if RUL>50

# %%
train_df['label1'] = np.where(train_df['RUL'] <= w1, 1, 2 )
train_df['label2'] = train_df['label1']
train_df.loc[train_df['RUL'] <= w0, 'label2'] = 0

label = ['RUL <= 20' if x==0 else '20 < RUL <= 50' if x==1 else 'RUL > 50' for x in train_df["label2"].value_counts().keys()]
label
# Out:
# ['RUL > 50', '20 < RUL <= 50', 'RUL <= 20']

# %% [markdown]
# ### Pie chart of categories

# %%
#labels

#values
val = train_df["label2"].value_counts().values.tolist()

trace = go.Pie(labels = label ,
               values = val ,
               marker = dict(colors =  [ 'blue' ,'green', 'red'],
                             line = dict(color = "white",
                                         width =  1.3)
                            ),
               rotation = 90,
               hoverinfo = "label+value+text",
               hole = .5
              )
layout = go.Layout(dict(title = "Remaining Useful Life of Aircraft Engine",
                        plot_bgcolor  = "rgb(243,243,243)",
                        paper_bgcolor = "rgb(243,243,243)",
                       )
                  )

data = [trace]
fig = go.Figure(data = data,layout = layout)
py.iplot(fig)
# Out:
# <div>
#
#
#             <div id="d43e9a7c-8ed2-4954-a91d-3d0ad7dc0fac" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("d43e9a7c-8ed2-4954-a91d-3d0ad7dc0fac")) {
#                     Plotly.newPlot(
#                         'd43e9a7c-8ed2-4954-a91d-3d0ad7dc0fac',
#                         [{"hole": 0.5, "hoverinfo": "label+value+text", "labels": ["RUL > 50", "20 < RUL <= 50", "RUL <= 20"], "marker": {"colors": ["blue", "green", "red"], "line": {"color": "white", "width": 1.3}}, "rotation": 90, "type": "pie", "values": [15531, 3000, 2100]}],
#                         {"paper_bgcolor": "rgb(243,243,243)", "plot_bgcolor": "rgb(243,243,243)", "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}},  ...

# %%
### ADD NEW LABEL TEST ###
test_df['label1'] = np.where(test_df['RUL'] <= w1, 1, 2 )
test_df['label2'] = test_df['label1']
test_df.loc[test_df['RUL'] <= w0, 'label2'] = 0

# %% [markdown]
# # Model Training
# Why have I chosen a specific model performance indicator?
#
# We will use the score of 'weighted avg f1' as the main metrics, combined with 'precision' and 'recall'
# ## Based model where we use only the current flight as input
#
# Why have I chosen a specific algorithm?
#
# RandomForest is one of the best traditional machine learning methods for cases with many features, and moreover it is less bias and low variance compared to other approaches.

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split, cross_val_score

train_y = train_df.label2
train_X = train_df.drop(['label1', 'label2', 'RUL', 'cycle', 'id'], axis='columns')

test_y  = test_df.label2
test_X = test_df.drop(['label1', 'label2', 'RUL', 'cycle', 'id'], axis='columns')

train_X.shape, train_y.shape, test_X.shape, test_y.shape
# Out:
# ((20631, 17), (20631,), (13096, 17), (13096,))

# %%
print('Input features:', train_X.columns.tolist())
# Out:
# Input features: ['setting_1', 'setting_2', 'T24', 'T30', 'T50', 'P15', 'P30', 'Nf', 'Nc', 'Ps30', 'phi', 'NRf', 'NRc', 'BPR', 'htBleed', 'W31', 'W32']

# %% [markdown]
# ### RandomForestClassifier

# %%
clf_1 = RandomForestClassifier(max_depth=8, random_state=7)
scores = cross_val_score(clf_1, train_X, train_y, cv=5)
print('Scores of n cross validation training', scores)

print('Cross validation mean score', np.mean(scores))
# Out:
# Scores of n cross validation training [0.92318876 0.90499273 0.90547746 0.89020843 0.8967523 ]
# Cross validation mean score 0.9041239365604963

# %%
model_1 = clf_1.fit(train_X, train_y)
pred_y = clf_1.predict(test_X)
print(f'Model Accuracy', accuracy_score(test_y, pred_y))
print(classification_report(test_y, pred_y))
# Out:
# Model Accuracy 0.7790164935858277
#               precision    recall  f1-score   support
#
#            0       0.19      0.98      0.32       123
#            1       0.12      0.41      0.18       763
#            2       0.99      0.80      0.89     12210
#
#     accuracy                           0.78     13096
#    macro avg       0.43      0.73      0.46     13096
# weighted avg       0.94      0.78      0.84     13096

# %% [markdown]
# ### Confusion matrix

# %%
from sklearn.metrics import ConfusionMatrixDisplay
cm = confusion_matrix(test_y, pred_y)

disp = ConfusionMatrixDisplay(confusion_matrix=cm/cm.sum(), display_labels=[0,1,2])
disp.plot(include_values=True,
                     cmap='viridis', ax=None,# xticks_rotation='horizontal',
                     values_format=None)
plt.grid('off')

# %%
importances = clf_1.feature_importances_
df = pd.DataFrame([train_X.columns.tolist(), importances.tolist()])
df
# Out:
#             0           1          2          3         4    5         6  \
# 0   setting_1   setting_2        T24        T30       T50  P15       P30
# 1  0.00427754  0.00253019  0.0263714  0.0176759  0.161279    0  0.107183
#
#             7          8         9        10         11         12         13  \
# 0          Nf         Nc      Ps30       phi        NRf        NRc        BPR
# 1  0.00982441  0.0883908  0.199009  0.111383  0.0151573  0.0694569  0.0673025
#
#           14        15         16
# 0    htBleed       W31        W32
# 1  0.0222622  0.037288  0.0606078

# %%
std = np.std([clf_1.feature_importances_ for tree in clf_1.estimators_],
             axis=0)
indices = np.argsort(importances)[::-1]

# Print the feature ranking
print("Feature ranking:")
for f in range(train_X.shape[1]):
    print("%d. feature %d - %s (%f)" % (f + 1, indices[f], train_X.columns.tolist()[indices[f]], importances[indices[f]]))

xtick = [train_X.columns.tolist()[indices[i]] for i in range(train_X.shape[1])] 

# Plot the feature importances of the forest
plt.figure()
plt.title("Feature importances")
plt.bar(range(train_X.shape[1]), importances[indices],
       color=list('rgbkymc'), yerr=std[indices], align="center")
plt.xticks(range(train_X.shape[1]), xtick, rotation=75)
plt.xlim([-1, train_X.shape[1]])
plt.show()
# Out:
# Feature ranking:
# 1. feature 9 - Ps30 (0.199009)
# 2. feature 4 - T50 (0.161279)
# 3. feature 10 - phi (0.111383)
# 4. feature 6 - P30 (0.107183)
# 5. feature 8 - Nc (0.088391)
# 6. feature 12 - NRc (0.069457)
# 7. feature 13 - BPR (0.067302)
# 8. feature 16 - W32 (0.060608)
# 9. feature 15 - W31 (0.037288)
# 10. feature 2 - T24 (0.026371)
# 11. feature 14 - htBleed (0.022262)
# 12. feature 3 - T30 (0.017676)
# 13. feature 11 - NRf (0.015157)
# 14. feature 7 - Nf (0.009824)
# 15. feature 0 - setting_1 (0.004278)
# 16. feature 1 - setting_2 (0.002530)
# 17. feature 5 - P15 (0.000000)

# %% [markdown]
# The list of important features here is matching with the correlation table in the section 3.3.
#
# Especially, the columns Ps30, T50, phi, P30, Nc, W32 are highly correlated to the RUL, hence, also to label1 and label2.
#
# **Remarks:** One of the reason that the Random Forest didn't work well is it haven't utilized all past data.

# %% [markdown]
# ## Generate sequence input data for the deep learning models
# Why have I chosen a specific framework?
#
# We will transform the data into the sequence format to input to our Recurrent neural network later on. In addition, we expect our model might remember the behaviour of the aircraft engine before the current flight.

# %%
sequence_length = 60

def gen_sequence(id_df, seq_length, seq_cols):

    data_matrix = id_df[seq_cols].values
    num_elements = data_matrix.shape[0]
    # Iterate over two lists in parallel.
    # For example id1 have 192 rows and sequence_length is equal to 50
    # so zip iterate over two following list of numbers (0,142),(50,192)
    # 0 50 (start stop) -> from row 0 to row 50
    # 1 51 (start stop) -> from row 1 to row 51
    # 2 52 (start stop) -> from row 2 to row 52
    # ...
    # 141 191 (start stop) -> from row 141 to 191
    for start, stop in zip(range(0, num_elements-seq_length), range(seq_length, num_elements)):
        yield data_matrix[start:stop, :]
        
def gen_labels(id_df, seq_length, label):

    data_matrix = id_df[label].values
    num_elements = data_matrix.shape[0]
    return data_matrix[seq_length:num_elements, :]

# %%
### SEQUENCE COL: COLUMNS TO CONSIDER ###
sequence_cols = train_df.columns.tolist()[2:-3]
print(sequence_cols)

nb_features = len(sequence_cols)
# Out:
# ['setting_1', 'setting_2', 'T24', 'T30', 'T50', 'P15', 'P30', 'Nf', 'Nc', 'Ps30', 'phi', 'NRf', 'NRc', 'BPR', 'htBleed', 'W31', 'W32']

# %%
### GENERATE X TRAIN TEST BY USING THE SEQUENCE INPUT ###
x_train, x_test = [], []
for engine_id in train_df.id.unique():
    for sequence in gen_sequence(train_df[train_df.id==engine_id], sequence_length, sequence_cols):
        x_train.append(sequence)
    for sequence in gen_sequence(test_df[test_df.id==engine_id], sequence_length, sequence_cols):
        x_test.append(sequence)
    
x_train = np.asarray(x_train)
x_test = np.asarray(x_test)

print("X_train shape:", x_train.shape)
print("X_test shape:", x_test.shape)
# Out:
# X_train shape: (14631, 60, 17)
# X_test shape: (7263, 60, 17)

# %%
### GENERATE Y TRAIN TEST ###
y_train, y_test = [], []
for engine_id in train_df.id.unique():
    for label in gen_labels(train_df[train_df.id==engine_id], sequence_length, ['label2'] ):
        y_train.append(label)
    for label in gen_labels(test_df[test_df.id==engine_id], sequence_length, ['label2']):
        y_test.append(label)
    
y_train = np.asarray(y_train).reshape(-1,1)
y_test = np.asarray(y_test).reshape(-1,1)

print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)
# Out:
# y_train shape: (14631, 1)
# y_test shape: (7263, 1)

# %%
### ENCODE LABEL ###
y_train = to_categorical(y_train)
print(y_train.shape)

y_test = to_categorical(y_test)
print(y_test.shape)
# Out:
# (14631, 3)
# (7263, 3)

# %% [markdown]
# ## Feed Forward network

# %%
ffn_filepath = "../hdf5_models/RUL_FFN.hdf5"
checkpoint = ModelCheckpoint(ffn_filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max', save_weights_only=False)

model_2 = Sequential()
# model.name= 'Classification'

model_2.add(Dense(32,
         input_shape=(sequence_length, nb_features), ## (50,17)
        activation = 'relu'))
model_2.add(Dropout(0.25))


model_2.add(Dense(64, activation = 'relu'))
model_2.add(Dropout(0.25))

model_2.add(Flatten())

model_2.add(Dense(units=3, activation='sigmoid'))
model_2.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['acc'])

print(model_2.summary())
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0501 04:26:26.034144 140531367757696 deprecation.py:506] From /home/philip/.virtualenvs/deep_learn_py3/lib/python3.6/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 60, 32)            576
# _________________________________________________________________
# dropout (Dropout)            (None, 60, 32)            0
# _________________________________________________________________
# dense_1 (Dense)              (None, 60, 64)            2112
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 60, 64)            0
# _________________________________________________________________
# flatten (Flatten)            (None, 3840)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 11523
# =================================================================
# Total params: 14,211
# Trainable params: 14,211
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ### FFN Training step

# %%
BATCH_SIZE = 256
EPOCHS = 25

history = model_2.fit(x_train,
                      y_train,
                      batch_size=BATCH_SIZE,
                      epochs=EPOCHS,
                      callbacks=[checkpoint],
                      validation_split=0.2,
                      verbose=1)
# Out:
# W0501 04:26:26.243235 140531367757696 deprecation.py:323] From /home/philip/.virtualenvs/deep_learn_py3/lib/python3.6/site-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Train on 11704 samples, validate on 2927 samples
# Epoch 1/25
# 11520/11704 [============================>.] - ETA: 0s - loss: 0.7637 - acc: 0.6754
# Epoch 00001: val_acc improved from -inf to 0.78681, saving model to ../hdf5_models/RUL_FFN.hdf5
# 11704/11704 [==============================] - 1s 79us/sample - loss: 0.7602 - acc: 0.6768 - val_loss: 0.4913 - val_acc: 0.7868
# Epoch 2/25
# 11264/11704 [===========================>..] - ETA: 0s - loss: 0.4765 - acc: 0.7930
# Epoch 00002: val_acc improved from 0.78681 to 0.80492, saving model to ../hdf5_models/RUL_FFN.hdf5
# 11704/11704 [==============================] - 1s 62us/sample - loss: 0.4745 - acc: 0.7938 - val_loss: 0.4332 - val_acc: 0.8049
# Epoch 3/25
# 11520/11704 [============================>.] - ETA: 0s - loss: 0.3882 - acc: 0.8306
# Epoch 00003: val_acc improved from 0.80492 to 0.84387, saving model to ../hdf5_models/RUL_FFN.hdf5
# 11704/11704 [==============================] - 1s 58us/sample - loss: 0.3872 - acc: 0.8310 - val_loss: 0.3452 - val_acc: 0.8439
# Epoch 4/25
# 11520/11704 [============================>.] - ETA: 0s - loss: 0.3272 - acc: 0.8614
# Epoch 00004: val_acc improved from 0.84387 to 0.87530, saving model to ../hdf5_models/RUL_FFN.hdf5
# 11704/11704 [==============================] - 1s 59us/sample - loss: 0.3260 - acc: 0.8622 - val_loss: 0.2889 - val_acc: 0.8753
# Epoch 5/25
# 11520/11704 [============================>.] - ETA: 0s - loss: 0.2760 - acc: 0.8808
# Epoch 00005: val_acc improved from 0.87530 to 0.88760, saving model to ../hdf5_models/RUL_FFN.hdf5
# 11704/11704 [==============================] - 1s 60us/sample - loss: 0.2761 - acc: 0.8811 - val_loss: 0.2606 - val_acc: 0.8876
# Epoch 6/25
# 11520/11704 [============================>.] - ETA: 0s - loss: 0.2531 - acc: 0.8911
# Epoch 00006: val_acc did not improve from 0.88760
# 11704/11704 [==============================] - 1s 57us/sample - loss: 0.2528 - acc: 0.8913 - val_loss: 0.2593 - val_acc: 0.8855
# Epoch 7/25
# 11520/11704 [============================>.] - ETA: 0s - loss: 0.2426 - acc: 0.8938
# Epoch 00007: val_acc improved from 0.88760 to 0.90434, saving model to ../hdf5_models/RUL_FFN.hdf5
# 11704/11704 [==============================] - 1s 59us/sample - loss: 0.2423 - acc: 0.8941 - val_loss: 0.2166 - val_acc: 0.9043
# Epoch 8/25
# 11520/11704 [============================>.] - ETA: 0s - loss: 0.2335 - acc: 0.9031
# Epoch 00008: val_acc did not improve from 0.90434
# 11704/11704 [==============================] - 1s 57us/sample - loss: 0.2343 - acc: 0.9028 - val_loss: 0.2282 - val_acc: 0.9002
# Epoch 9/25
# 11520/11704 [============================>.] - ETA: 0s - loss: 0.2286 - acc: 0.9025
# Epoch 00009: val_acc did not improve from 0.90434
# 11704/11704 [==============================] - 1s 57us/sample - loss: 0.2275 - acc: 0.9028 - val_loss: 0.2225 - val_acc: 0.8982
# Epoch 10/25
# 11520/11704 [============================>.] - ETA: 0s - loss: 0.2152 - acc: 0.9050
# Epoch 00010: val_acc improved from 0.90434 to 0.91254, saving model to ../hdf5_models/RUL_FFN.hdf5
# 11704/11704 [==============================] - 1s 59us/sample - loss: 0.2155 - acc: 0.9049 - val_loss: 0.1903 - val_acc: 0.9125
# Epoch 11/25
# 10752/11704 [==========================>...] - ETA: 0s - loss: 0.2068 - acc: 0.9077
# Epoch 00011: val_acc did not improve from 0.91254
# 11704/11704 [==============================] - 1s 62us/sample - loss: 0.2072 - acc: 0.9077 - val_loss: 0.1961 - val_acc: 0.9095
# Epoch 12/25
# 11520/11704 [============================>.] - ETA: 0s - loss: 0.1998 - acc: 0.9118
# Epoch 00012: val_acc did not improve from 0.91254
# 11704/11704 [==============================] - 1s 58us/sample - loss: 0.1992 - acc: 0.9121 - val_loss: 0.1923 - val_acc: 0.9115
# Epoch 13/25
# 11520/11704 [============================>.] - ETA: 0s - loss: 0.1972 - acc: 0.9133
# Epoch 00013: val_acc improved from 0.91254 to 0.91459, saving model to ../hdf5_models/RUL_FFN.hdf5
# 11704/11704 [==============================] - 1s 59us/sample - loss: 0.1974 - acc: 0.9134 - val_loss: 0.1892 - val_acc: 0.9146
# Epoch 14/25
# 11264/11704 [===========================>..] - ETA: 0s - loss: 0.1906 - acc: 0.9196
# Epoch 00014: val_acc improved from 0.91459 to 0.92415, saving model to ../hdf5_models/RUL_FFN.hdf5
# 11704/11704 [==============================] - 1s 66us/sample - loss: 0.1919 - acc: 0.9186 - val_loss: 0.1739 - val_acc: 0.9242
# Epoch 15/25
# 11520/11704 [============================>.] - ETA: 0s - loss: 0.1887 - acc: 0.9222
# Epoch 00015: val_acc did not improve from 0.92415
# 11704/11704 [==============================] - 1s 64us/sample - loss: 0.1890 - acc: 0.9222 - val_loss: 0.1770 - val_acc: 0.9183
# Epoch 16/25
# 11264/11704 [===========================>..] - ETA: 0s - loss: 0.1880 - acc: 0.9190
# Epoch 00016: val_acc did not improve from 0.92415
# 11704/11704 [==============================] - 1s 65us/sample - loss: 0.1878 - acc: 0.9193 - val_loss: 0.1667 - val_acc: 0.9238
# Epoch 17/25
# 11520/11704 [============================>.] - ETA: 0s - loss: 0.1792 - acc: 0.9266
# Epoch 00017: val_acc did not improve from 0.92415
# 11704/11704 [==============================] - 1s 64us/sample - loss: 0.1788 - acc: 0.9264 - val_loss: 0.1698 - val_acc: 0.9201
# Epoch 18/25
# 11008/11704 [===========================>..] - ETA: 0s - loss: 0.1835 - acc: 0.9227
# Epoch 00018: val_acc did not improve from 0.92415
# 11704/11704 [==============================] - 1s 66us/sample - loss: 0.1844 - acc: 0.9221 - val_loss: 0.1845 - val_acc: 0.9166
# Epoch 19/25
# 11264/11704 [===========================>..] - ETA: 0s - loss: 0.1833 - acc: 0.9233
# Epoch 00019: val_acc improved from 0.92415 to 0.92586, saving model to ../hdf5_models/RUL_FFN.hdf5
# 11704/11704 [==============================] - 1s 61us/sample - loss: 0.1824 - acc: 0.9233 - val_loss: 0.1694 - val_acc: 0.9259
# Epoch 20/25
# 11520/11704 [============================>.] - ETA: 0s - loss: 0.1722 - acc: 0.9232
# Epoch 00020: val_acc did not improve from 0.92586
# 11704/11704 [==============================] - 1s 67us/sample - loss: 0.1727 - acc: 0.9231 - val_loss: 0.1686 - val_acc: 0.9259
# Epoch 21/25
# 11520/11704 [============================>.] - ETA: 0s - loss: 0.1728 - acc: 0.9253
# Epoch 00021: val_acc did not improve from 0.92586
# 11704/11704 [==============================] - 1s 60us/sample - loss: 0.1725 - acc: 0.9257 - val_loss: 0.1589 - val_acc: 0.9252
# Epoch 22/25
# 11008/11704 [===========================>..] - ETA: 0s - loss: 0.1747 - acc: 0.9261
# Epoch 00022: val_acc did not improve from 0.92586
# 11704/11704 [==============================] - 1s 64us/sample - loss: 0.1746 - acc: 0.9264 - val_loss: 0.1683 - val_acc: 0.9221
# Epoch 23/25
# 11264/11704 [===========================>..] - ETA: 0s - loss: 0.1773 - acc: 0.9237
# Epoch 00023: val_acc did not improve from 0.92586
# 11704/11704 [==============================] - 1s 77us/sample - loss: 0.1768 - acc: 0.9240 - val_loss: 0.1621 - val_acc: 0.9224
# Epoch 24/25
# 11264/11704 [===========================>..] - ETA: 0s - loss: 0.1699 - acc: 0.9274
# Epoch 00024: val_acc did not improve from 0.92586
# 11704/11704 [==============================] - 1s 72us/sample - loss: 0.1732 - acc: 0.9261 - val_loss: 0.1658 - val_acc: 0.9231
# Epoch 25/25
# 11264/11704 [===========================>..] - ETA: 0s - loss: 0.1694 - acc: 0.9269
# Epoch 00025: val_acc did not improve from 0.92586
# 11704/11704 [==============================] - 1s 66us/sample - loss: 0.1687 - acc: 0.9275 - val_loss: 0.1670 - val_acc: 0.9224

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'acc', 'val_loss', 'val_acc'])

# %%
# summarize history for Accuracy
fig_acc = plt.figure(figsize=(10, 10))
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('acc')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
fig_acc.savefig("../training/fnn_model_accuracy.png")

# summarize history for Loss
fig_acc = plt.figure(figsize=(10, 10))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
fig_acc.savefig("../training/fnn_model_loss.png")

# %%
### LOAD BEST MODEL ###
best_model = load_model(ffn_filepath)

model_2.evaluate(x_test, y_test, verbose=1)[1]
# Out:
# W0501 04:26:45.694294 140531367757696 deprecation.py:506] From /home/philip/.virtualenvs/deep_learn_py3/lib/python3.6/site-packages/tensorflow_core/python/ops/init_ops.py:97: calling GlorotUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0501 04:26:45.696167 140531367757696 deprecation.py:506] From /home/philip/.virtualenvs/deep_learn_py3/lib/python3.6/site-packages/tensorflow_core/python/ops/init_ops.py:97: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# 7263/7263 [==============================] - 0s 48us/sample - loss: 0.7097 - acc: 0.8044
# 0.8043508

# %%
y_pred_origin = model_2.predict(x_test)
y_pred = np.argmax(y_pred_origin, axis=1)

# %%
y_test = np.argmax(y_test, axis=1)
print('accuracy', accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# accuracy 0.8043508192207077
#               precision    recall  f1-score   support
#
#            0       0.26      1.00      0.41       123
#            1       0.28      0.53      0.36       763
#            2       1.00      0.83      0.91      6377
#
#     accuracy                           0.80      7263
#    macro avg       0.51      0.79      0.56      7263
# weighted avg       0.91      0.80      0.84      7263

# %% [markdown]
# ### Confusion matrix

# %%
from sklearn.metrics import ConfusionMatrixDisplay
cm = confusion_matrix(y_test, y_pred)

disp = ConfusionMatrixDisplay(confusion_matrix=cm/cm.sum(), display_labels=[0,1,2])
disp.plot(include_values=True,
                     cmap='viridis', ax=None,# xticks_rotation='horizontal',
                     values_format=None)
plt.grid('off')

# %% [markdown]
# ## Recurrent Neural Network

# %%
rnn_filepath = "../hdf5_models/RUL_RNN.hdf5"
checkpoint = ModelCheckpoint(rnn_filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max', save_weights_only=False)

model_3 = Sequential()
# model.name= 'Classification'
model_3.add(LSTM(
         input_shape=(sequence_length, nb_features), ## (50,17)
         units=120,
         return_sequences=True))
model_3.add(Dropout(0.25))


model_3.add(LSTM(
          units=60,
          return_sequences=False))
model_3.add(Dropout(0.25))

model_3.add(Dense(units=3, activation='sigmoid'))
model_3.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['acc'])

print(model_3.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 60, 120)           66240
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 60, 120)           0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 60)                43440
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 60)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 3)                 183
# =================================================================
# Total params: 109,863
# Trainable params: 109,863
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ### RNN Training step

# %%
BATCH_SIZE = 256
EPOCHS = 25

history = model_3.fit(x_train,
                      y_train,
                      batch_size=BATCH_SIZE,
                      epochs=EPOCHS,
                      callbacks=[checkpoint],
                      validation_split=0.2,
                      verbose=1)
# Out:
# Train on 11704 samples, validate on 2927 samples
# Epoch 1/25
# 11520/11704 [============================>.] - ETA: 0s - loss: 0.7136 - acc: 0.7051
# Epoch 00001: val_acc improved from -inf to 0.80799, saving model to ../hdf5_models/RUL_RNN.hdf5
# 11704/11704 [==============================] - 10s 848us/sample - loss: 0.7102 - acc: 0.7070 - val_loss: 0.4416 - val_acc: 0.8080
# Epoch 2/25
# 11520/11704 [============================>.] - ETA: 0s - loss: 0.3534 - acc: 0.8629
# Epoch 00002: val_acc improved from 0.80799 to 0.86573, saving model to ../hdf5_models/RUL_RNN.hdf5
# 11704/11704 [==============================] - 9s 768us/sample - loss: 0.3540 - acc: 0.8624 - val_loss: 0.2973 - val_acc: 0.8657
# Epoch 3/25
# 11520/11704 [============================>.] - ETA: 0s - loss: 0.2557 - acc: 0.8973
# Epoch 00003: val_acc improved from 0.86573 to 0.87667, saving model to ../hdf5_models/RUL_RNN.hdf5
# 11704/11704 [==============================] - 9s 745us/sample - loss: 0.2547 - acc: 0.8978 - val_loss: 0.2783 - val_acc: 0.8767
# Epoch 4/25
# 11520/11704 [============================>.] - ETA: 0s - loss: 0.2337 - acc: 0.9030
# Epoch 00004: val_acc improved from 0.87667 to 0.88965, saving model to ../hdf5_models/RUL_RNN.hdf5
# 11704/11704 [==============================] - 9s 777us/sample - loss: 0.2332 - acc: 0.9033 - val_loss: 0.2544 - val_acc: 0.8896
# Epoch 5/25
# 11520/11704 [============================>.] - ETA: 0s - loss: 0.2126 - acc: 0.9119
# Epoch 00005: val_acc improved from 0.88965 to 0.92723, saving model to ../hdf5_models/RUL_RNN.hdf5
# 11704/11704 [==============================] - 9s 758us/sample - loss: 0.2120 - acc: 0.9123 - val_loss: 0.1783 - val_acc: 0.9272
# Epoch 6/25
# 11520/11704 [============================>.] - ETA: 0s - loss: 0.1857 - acc: 0.9213
# Epoch 00006: val_acc did not improve from 0.92723
# 11704/11704 [==============================] - 9s 748us/sample - loss: 0.1869 - acc: 0.9210 - val_loss: 0.2106 - val_acc: 0.9177
# Epoch 7/25
# 11520/11704 [============================>.] - ETA: 0s - loss: 0.1845 - acc: 0.9251
# Epoch 00007: val_acc did not improve from 0.92723
# 11704/11704 [==============================] - 9s 744us/sample - loss: 0.1844 - acc: 0.9252 - val_loss: 0.1736 - val_acc: 0.9272
# Epoch 8/25
# 11520/11704 [============================>.] - ETA: 0s - loss: 0.1727 - acc: 0.9258
# Epoch 00008: val_acc did not improve from 0.92723
# 11704/11704 [==============================] - 9s 757us/sample - loss: 0.1728 - acc: 0.9258 - val_loss: 0.1992 - val_acc: 0.9194
# Epoch 9/25
# 11520/11704 [============================>.] - ETA: 0s - loss: 0.1800 - acc: 0.9237
# Epoch 00009: val_acc did not improve from 0.92723
# 11704/11704 [==============================] - 9s 782us/sample - loss: 0.1797 - acc: 0.9235 - val_loss: 0.1749 - val_acc: 0.9197
# Epoch 10/25
# 11520/11704 [============================>.] - ETA: 0s - loss: 0.1725 - acc: 0.9255
# Epoch 00010: val_acc did not improve from 0.92723
# 11704/11704 [==============================] - 9s 765us/sample - loss: 0.1730 - acc: 0.9254 - val_loss: 0.1792 - val_acc: 0.9183
# Epoch 11/25
# 11520/11704 [============================>.] - ETA: 0s - loss: 0.1663 - acc: 0.9265
# Epoch 00011: val_acc did not improve from 0.92723
# 11704/11704 [==============================] - 9s 748us/sample - loss: 0.1670 - acc: 0.9260 - val_loss: 0.2084 - val_acc: 0.9119
# Epoch 12/25
# 11520/11704 [============================>.] - ETA: 0s - loss: 0.1604 - acc: 0.9307
# Epoch 00012: val_acc improved from 0.92723 to 0.93577, saving model to ../hdf5_models/RUL_RNN.hdf5
# 11704/11704 [==============================] - 9s 763us/sample - loss: 0.1603 - acc: 0.9310 - val_loss: 0.1494 - val_acc: 0.9358
# Epoch 13/25
# 11520/11704 [============================>.] - ETA: 0s - loss: 0.1754 - acc: 0.9251
# Epoch 00013: val_acc did not improve from 0.93577
# 11704/11704 [==============================] - 9s 771us/sample - loss: 0.1758 - acc: 0.9250 - val_loss: 0.1753 - val_acc: 0.9238
# Epoch 14/25
# 11520/11704 [============================>.] - ETA: 0s - loss: 0.1532 - acc: 0.9339
# Epoch 00014: val_acc did not improve from 0.93577
# 11704/11704 [==============================] - 9s 782us/sample - loss: 0.1531 - acc: 0.9339 - val_loss: 0.1638 - val_acc: 0.9310
# Epoch 15/25
# 11520/11704 [============================>.] - ETA: 0s - loss: 0.1596 - acc: 0.9319
# Epoch 00015: val_acc did not improve from 0.93577
# 11704/11704 [==============================] - 9s 788us/sample - loss: 0.1596 - acc: 0.9319 - val_loss: 0.1877 - val_acc: 0.9231
# Epoch 16/25
# 11520/11704 [============================>.] - ETA: 0s - loss: 0.1704 - acc: 0.9291
# Epoch 00016: val_acc did not improve from 0.93577
# 11704/11704 [==============================] - 9s 750us/sample - loss: 0.1701 - acc: 0.9291 - val_loss: 0.1851 - val_acc: 0.9231
# Epoch 17/25
# 11520/11704 [============================>.] - ETA: 0s - loss: 0.1516 - acc: 0.9356
# Epoch 00017: val_acc did not improve from 0.93577
# 11704/11704 [==============================] - 10s 849us/sample - loss: 0.1512 - acc: 0.9357 - val_loss: 0.1829 - val_acc: 0.9197
# Epoch 18/25
# 11520/11704 [============================>.] - ETA: 0s - loss: 0.1522 - acc: 0.9359
# Epoch 00018: val_acc did not improve from 0.93577
# 11704/11704 [==============================] - 11s 911us/sample - loss: 0.1528 - acc: 0.9357 - val_loss: 0.1796 - val_acc: 0.9207
# Epoch 19/25
# 11520/11704 [============================>.] - ETA: 0s - loss: 0.1448 - acc: 0.9384
# Epoch 00019: val_acc did not improve from 0.93577
# 11704/11704 [==============================] - 10s 843us/sample - loss: 0.1449 - acc: 0.9382 - val_loss: 0.1946 - val_acc: 0.9218
# Epoch 20/25
# 11520/11704 [============================>.] - ETA: 0s - loss: 0.1585 - acc: 0.9318
# Epoch 00020: val_acc did not improve from 0.93577
# 11704/11704 [==============================] - 9s 796us/sample - loss: 0.1590 - acc: 0.9316 - val_loss: 0.1627 - val_acc: 0.9330
# Epoch 21/25
# 11520/11704 [============================>.] - ETA: 0s - loss: 0.1381 - acc: 0.9404
# Epoch 00021: val_acc did not improve from 0.93577
# 11704/11704 [==============================] - 9s 789us/sample - loss: 0.1395 - acc: 0.9394 - val_loss: 0.1601 - val_acc: 0.9296
# Epoch 22/25
# 11520/11704 [============================>.] - ETA: 0s - loss: 0.1483 - acc: 0.9376
# Epoch 00022: val_acc did not improve from 0.93577
# 11704/11704 [==============================] - 10s 834us/sample - loss: 0.1480 - acc: 0.9380 - val_loss: 0.1685 - val_acc: 0.9279
# Epoch 23/25
# 11520/11704 [============================>.] - ETA: 0s - loss: 0.1421 - acc: 0.9401
# Epoch 00023: val_acc did not improve from 0.93577
# 11704/11704 [==============================] - 11s 927us/sample - loss: 0.1416 - acc: 0.9403 - val_loss: 0.1653 - val_acc: 0.9344
# Epoch 24/25
# 11520/11704 [============================>.] - ETA: 0s - loss: 0.1552 - acc: 0.9328
# Epoch 00024: val_acc improved from 0.93577 to 0.93680, saving model to ../hdf5_models/RUL_RNN.hdf5
# 11704/11704 [==============================] - 9s 750us/sample - loss: 0.1545 - acc: 0.9332 - val_loss: 0.1548 - val_acc: 0.9368
# Epoch 25/25
# 11520/11704 [============================>.] - ETA: 0s - loss: 0.1489 - acc: 0.9365
# Epoch 00025: val_acc did not improve from 0.93680
# 11704/11704 [==============================] - 9s 790us/sample - loss: 0.1491 - acc: 0.9365 - val_loss: 0.1574 - val_acc: 0.9317

# %%
# summarize history for Accuracy
fig_acc = plt.figure(figsize=(10, 10))
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('acc')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
fig_acc.savefig("../training/rnn_model_accuracy.png")

# summarize history for Loss
fig_acc = plt.figure(figsize=(10, 10))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
fig_acc.savefig("../training/rnn_model_loss.png")

# %%
y_pred_origin = model_3.predict(x_test)
y_pred = np.argmax(y_pred_origin, axis=1)
print('accuracy', accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# accuracy 0.7580889439625499
#               precision    recall  f1-score   support
#
#            0       0.16      1.00      0.28       123
#            1       0.19      0.35      0.25       763
#            2       1.00      0.80      0.89      6377
#
#     accuracy                           0.76      7263
#    macro avg       0.45      0.72      0.47      7263
# weighted avg       0.90      0.76      0.81      7263

# %%
y_pred_origin, y_pred, y_test
# Out:
# (array([[1.2654066e-04, 3.5263598e-03, 9.6944773e-01],
#         [1.2907386e-04, 3.5398901e-03, 9.6790850e-01],
#         [1.2558699e-04, 3.1863749e-03, 9.6849370e-01],
#         ...,
#         [9.7885215e-01, 3.2027364e-03, 3.9246678e-04],
#         [9.7934258e-01, 3.1917125e-03, 3.9384092e-04],
#         [9.7975069e-01, 3.1841723e-03, 3.9385183e-04]], dtype=float32),
#  array([2, 2, 2, ..., 0, 0, 0]),
#  array([2, 2, 2, ..., 1, 1, 0]))

# %% [markdown]
# ### Confusion matrix

# %%
from sklearn.metrics import ConfusionMatrixDisplay
cm = confusion_matrix(y_test, y_pred)

disp = ConfusionMatrixDisplay(confusion_matrix=cm/cm.sum(), display_labels=[0,1,2])
disp.plot(include_values=True,
                     cmap='viridis', ax=None,# xticks_rotation='horizontal',
                     values_format=None)
plt.grid('off')

# %% [markdown]
# # Final Remark
# + The model is rather sensitive on the two thresholds of w0 and w1.
# + We might still want to tune the Deep learning models (both FFN and RNN) further for better results
# + A regression model can also be built to predict the RUL of aircraft engine.

# %% [markdown]
# # References
#
# - [1] A. Saxena and K. Goebel (2008). "Turbofan Engine Degradation Simulation Data Set", NASA Ames Prognostics Data Repository (https://ti.arc.nasa.gov/tech/dash/groups/pcoe/prognostic-data-repository/#turbofan), NASA Ames Research Center, Moffett Field, CA
#
# - [2] Deep Learning for Predictive Maintenance https://github.com/Azure/lstms_for_predictive_maintenance/blob/master/Deep%20Learning%20Basics%20for%20Predictive%20Maintenance.ipynb
#
# - [3] Understanding LSTM Networks http://colah.github.io/posts/2015-08-Understanding-LSTMs/
